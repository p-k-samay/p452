# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ### P K SAMAY 2011102

# %% [markdown]
# ### Q1

# %%
f=lambda x:math.log(0.5*x) - math.sin(2.5*x)
d=lambda x:((1/x) - (2.5*math.cos(2.5*x)))
print("Regula Falsi")
regula_falsi(f,1.5,2.5)
print("")
print("Newton Raphson")
newton_raphson(f,d,2.2)
# Out:
# Regula Falsi
# 11.801724402995978
# 3.331808148122123
# 2.6129970798432707
# 2.650113267327452
# 2.6232515278445754
# 2.623140751344172
# No. of Iterations: 6
# The root is: 2.623140751344172
#
# Newton Raphson
# 2.8080273965694733
# 2.585564275463139
# 2.6227428603830814
# 2.6231402751560946
# No. of Iterations: 4
# The root is: 2.6231402751560946

# %% [markdown]
# ### Q2

# %%
position = shooter(40,200,100,1000)
print(f"The value of x: {position: 1.4f} where the temperature is 100 Degrees Celsius")
plt.xlabel("Position")
plt.ylabel("Temp")
plt.show()
# Out:
# The value of x:  4.4300 where the temperature is 100 Degrees Celsius

# %% [markdown]
# ### Q3

# %%
pde(2,30,1,5000)
# Out:
# The value of alpha is 0.045000000000000005
# alpha < 0.5 is satisfied

# %% [markdown]
# ### Q4

# %%
f=lambda x:x**2
xf=lambda x:x**3

a = simpsons(f,0,2,10)
b = simpsons(xf,0,2,10)
C = b/a
print (f'The center of mass of the rod is {C:.4f}')
# Out:
# The center of mass of the rod is 1.5000

# %% [markdown]
# ### Q5

# %%
A = np.array([[1,-1,4,0,2,9],
              [0,5,-2,7,8,4],
              [1,0,5,7,3,-2],
              [6,-1,2,3,0,8],
              [-4,2,0,5,-5,3],
              [0,7,-1,5,4,-2]])

b = np.array([19,2,13,-7,-9,2])

L, U = lu_decomposition(A)
y = forward_substitution(L, b)
x = backward_substitution(U, y)

print("Solution:", x)
# Out:
# Solution: [-1.76181704  0.89622803  4.0519314  -1.6171308   2.04191354  0.15183249]
